# %% [markdown]
# # 目標:
#
#  安裝Basemap, 並且可以使用它繪製地理資訊. 這個教程中，我們將涉及地理繪圖module: Basemap。Basemap是Matplotlib的擴展.
#
# # 重點:
#  Basemap 在地圖集上的擴展應用
#
#
# # 作業:
#
#  1. 更改 Projection 的設定繪製出地球儀圖形
#
#  當 "projection" 參數為“ortho"時，所得圖位地球儀截面
#
#  當 "projection" 參數為“Mill"時，所得平展位面
#
#
#  2. 查看 resolution / 經緯度座標的繪圖精細度

# %%
# !pip install geos
# !pip install pyproj
# Out:
# Requirement already satisfied: geos in c:\users\gordo\anaconda3\lib\site-packages (0.2.2)
# Requirement already satisfied: pillow in c:\users\gordo\anaconda3\lib\site-packages (from geos) (6.2.0)
# Requirement already satisfied: lxml in c:\users\gordo\anaconda3\lib\site-packages (from geos) (4.4.1)
# Requirement already satisfied: flask in c:\users\gordo\anaconda3\lib\site-packages (from geos) (1.1.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\gordo\anaconda3\lib\site-packages (from flask->geos) (0.16.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\gordo\anaconda3\lib\site-packages (from flask->geos) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\gordo\anaconda3\lib\site-packages (from flask->geos) (2.10.3)
# Requirement already satisfied: click>=5.1 in c:\users\gordo\anaconda3\lib\site-packages (from flask->geos) (7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\gordo\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->geos) (1.1.1)
# Requirement already satisfied: pyproj in c:\users\gordo\anaconda3\lib\site-packages (3.0.0.post1)
# Requirement already satisfied: certifi in c:\users\gordo\anaconda3\lib\site-packages (from pyproj) (2019.9.11)

# %%
# 載入套件
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install basemap
# Out:
# Collecting basemap
#   ERROR: Could not find a version that satisfies the requirement basemap (from versions: none)
# ERROR: No matching distribution found for basemap

# %%
# 創建基本地圖。
# 當 "projection" 參數為“ortho"時，所得圖位地球儀截面

from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
#設定圖形大小
plt.figure(figsize = (5,5))

#設定投影型態
m=Basemap(projection='ortho',resolution=None,lat_0=50,lon_0=-100)

#設定圖形顏色, 選用NASA 寶石藍輸出 
m.bluemarble(scale=0.5)

#秀圖
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-499848c77a91> in <module>
#       2 # 當 "projection" 參數為“ortho"時，所得圖位地球儀截面
#       3
# ----> 4 from mpl_toolkits.basemap import Basemap
#       5 import matplotlib.pyplot as plt
#       6 import numpy as np
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
m = Basemap(projection='mill',
            llcrnrlat = -90,
            llcrnrlon = -180,
            urcrnrlat = 90,
            urcrnrlon = 180,
           resolution='c') # 成圖設定resolution 

#創建邊線
m.drawcoastlines()
#畫出國家，並使用線寬為2 的線條生成分界線。
m.drawcountries(linewidth=2)
#畫出州界
m.drawstates(color='b')
#畫出城市
m.drawcounties(color='darkred')

plt.title('Basemap Tutorial')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-51fb7465d137> in <module>
# ----> 1 m = Basemap(projection='mill',
#       2             llcrnrlat = -90,
#       3             llcrnrlon = -180,
#       4             urcrnrlat = 90,
#       5             urcrnrlon = 180,
#
# NameError: name 'Basemap' is not defined

# %%
#設置Lambert保形底圖。
#set resolution = None跳過邊界數據集的處理
# projection='lcc'

m = Basemap(width=12000000,height=9000000,projection='lcc',
            resolution=None,lat_1=45.,lat_2=55,lat_0=50,lon_0=-107.)

#選用NASA 寶石藍輸出 
m.bluemarble()

#秀圖
plt.show()
